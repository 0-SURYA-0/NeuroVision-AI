# %%
import sys
import os
import time
import warnings
from pathlib import Path
from typing import Dict, List, Tuple, Optional, Union, Any
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.cuda.amp import autocast
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from tqdm import tqdm
import pickle
import json
from scipy.ndimage import zoom, gaussian_filter
from skimage.measure import label
from skimage.morphology import remove_small_objects, binary_closing

sys.path.append(r"c:\Users\surya\NueroVisionAI\core\3D architecture")

from utils_3d import Config, setup_logging, get_device, timer, format_time, load_nifti, save_nifti
from model_3d import UNet3D, create_unet3d
from dataset_3d import BraTSDataset
from preprocess_3d import VolumePreprocessor, preprocess_for_inference
from postprocess_3d import PostProcessor3D
from visualize_3d import VolumeVisualizer
from inference_3d import ModelInference, InferenceResult
from metrics_3d import SegmentationMetrics

os.environ['PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION'] = 'python'
warnings.filterwarnings('ignore')

print("🧠" * 50)
print("3D BRAIN TUMOR SEGMENTATION INFERENCE")
print("PRODUCTION-READY INFERENCE PIPELINE")
print("🧠" * 50)

device = get_device("auto")
print(f"\n🔥 GPU STATUS:")
print(f"├── Device: {device}")
if torch.cuda.is_available():
    print(f"├── GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"├── CUDA Version: {torch.version.cuda}")
    print(f"├── PyTorch Version: {torch.__version__}")
    print(f"└── Mixed Precision: ENABLED ✅")
else:
    print(f"└── CPU Mode: Enabled")

config = Config()
config.input_size = (64, 64, 64)
config.model_name = "light"
config.base_filters = 16
config.depth = 3
config.device = "auto"
config.mixed_precision = True
config.data_dir = r"c:\Users\surya\NueroVisionAI\data\BrainWithTumor"
config.output_dir = r"c:\Users\surya\NueroVisionAI\outputs\3d"
config.checkpoint_dir = r"c:\Users\surya\NueroVisionAI\checkpoints\3d"

use_tta = True
use_uncertainty = True
confidence_threshold = 0.5
min_tumor_size = 50
model_path = r"c:\Users\surya\NueroVisionAI\outputs\3d\unet3d_model.pkl"
checkpoint_path = r"c:\Users\surya\NueroVisionAI\checkpoints\3d\best_model.pth"

print(f"\n🔧 INFERENCE CONFIGURATION:")
print(f"├── Model: {config.model_name} 3D U-Net")
print(f"├── Volume Size: {config.input_size}")
print(f"├── Mixed Precision: {'✅ ENABLED' if config.mixed_precision else '❌ DISABLED'}")
print(f"├── Test-Time Augmentation: {'✅ ENABLED' if use_tta else '❌ DISABLED'}")
print(f"├── Uncertainty Estimation: {'✅ ENABLED' if use_uncertainty else '❌ DISABLED'}")
print(f"└── Confidence Threshold: {confidence_threshold}")

Path(config.output_dir).mkdir(parents=True, exist_ok=True)
# Out:
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
# 3D BRAIN TUMOR SEGMENTATION INFERENCE
# PRODUCTION-READY INFERENCE PIPELINE
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# 🔥 GPU STATUS:
# ├── Device: cuda
# ├── GPU Name: NVIDIA GeForce RTX 4060 Laptop GPU
# ├── CUDA Version: 11.8
# ├── PyTorch Version: 2.4.1+cu118
# └── Mixed Precision: ENABLED ✅
#
# 🔧 INFERENCE CONFIGURATION:
# ├── Model: light 3D U-Net
# ├── Volume Size: (64, 64, 64)
# ├── Mixed Precision: ✅ ENABLED
# ├── Test-Time Augmentation: ✅ ENABLED
# ├── Uncertainty Estimation: ✅ ENABLED
# └── Confidence Threshold: 0.5

# %%
print(f"\n🧠 LOADING TRAINED MODEL...")

model = create_unet3d(config.model_name).to(device)

try:
    if Path(checkpoint_path).exists():
        print(f"📂 Loading checkpoint: {checkpoint_path}")
        checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=False)
        model.load_state_dict(checkpoint['model_state_dict'])
        best_val_dice = checkpoint.get('best_val_dice', 0.0)
        print(f"✅ Checkpoint loaded! Best validation Dice: {best_val_dice:.4f}")
    elif Path(model_path).exists():
        print(f"📂 Loading model weights: {model_path}")
        model.load_state_dict(torch.load(model_path, map_location=device, weights_only=True))
        print(f"✅ Model weights loaded!")
    else:
        print(f"⚠️  No trained model found. Using randomly initialized weights.")
except Exception as e:
    print(f"❌ Error loading model: {str(e)}")
    print(f"⚠️  Using randomly initialized weights.")

model.eval()

num_params = sum(p.numel() for p in model.parameters())
model_size_mb = num_params * 4 / (1024 * 1024)

print(f"\n✅ MODEL READY FOR INFERENCE:")
print(f"├── Architecture: {config.model_name.upper()} 3D U-Net")
print(f"├── Total parameters: {num_params:,}")
print(f"├── Model size: {model_size_mb:.1f} MB")
print(f"├── Input channels: 4 (T1, T1CE, T2, FLAIR)")
print(f"├── Output channels: 1 (tumor segmentation)")
print(f"└── Device: {next(model.parameters()).device}")

preprocessor = VolumePreprocessor(config)
postprocessor = PostProcessor3D(config)
visualizer = VolumeVisualizer()

print(f"\n🔧 INFERENCE COMPONENTS INITIALIZED:")
print(f"├── Volume Preprocessor: Ready")
print(f"├── Post Processor: Ready")
print(f"├── Visualizer: Ready")
print(f"└── Components: Ready")
# Out:
# 🧠 LOADING TRAINED MODEL...
# 📂 Loading checkpoint: c:\Users\surya\NueroVisionAI\checkpoints\3d\best_model.pth
# ✅ Checkpoint loaded! Best validation Dice: 0.8974
#
# ✅ MODEL READY FOR INFERENCE:
# ├── Architecture: LIGHT 3D U-Net
# ├── Total parameters: 1,402,561
# ├── Model size: 5.4 MB
# ├── Input channels: 4 (T1, T1CE, T2, FLAIR)
# ├── Output channels: 1 (tumor segmentation)
# └── Device: cuda:0
#
# 🔧 INFERENCE COMPONENTS INITIALIZED:
# ├── Volume Preprocessor: Ready
# ├── Post Processor: Ready
# ├── Visualizer: Ready
# └── Components: Ready
# 📂 Loading checkpoint: c:\Users\surya\NueroVisionAI\checkpoints\3d\best_model.pth
# ✅ Checkpoint loaded! Best validation Dice: 0.8974
#
# ✅ MODEL READY FOR INFERENCE:
# ├── Architecture: LIGHT 3D U-Net
# ├── Total parameters: 1,402,561
# ├── Model size: 5.4 MB
# ├── Input channels: 4 (T1, T1CE, T2, FLAIR)
# ├── Output channels: 1 (tumor segmentation)
# └── Device: cuda:0
#
# 🔧 INFERENCE COMPONENTS INITIALIZED:
# ├── Volume Preprocessor: Ready
# ├── Post Processor: Ready
# ├── Visualizer: Ready
# └── Components: Ready

# %%
class InferenceEngine:
    def __init__(self, model, config, preprocessor, postprocessor, use_tta=True, use_uncertainty=True, confidence_threshold=0.5):
        self.model = model
        self.config = config
        self.preprocessor = preprocessor
        self.postprocessor = postprocessor
        self.device = next(model.parameters()).device
        self.use_tta = use_tta
        self.use_uncertainty = use_uncertainty
        self.confidence_threshold = confidence_threshold
        
    @torch.no_grad()
    def predict_single(self, volume_dict, use_tta=True, return_uncertainty=False):
        self.model.eval()
        
        if 'synthetic_volume' in volume_dict:
            input_tensor = torch.from_numpy(volume_dict['synthetic_volume']).unsqueeze(0).float().to(self.device)
        else:
            preprocessed_result = preprocess_for_inference(volume_dict, self.config)
            processed_volume = preprocessed_result['preprocessed_data']
            input_tensor = torch.from_numpy(processed_volume).unsqueeze(0).float().to(self.device)
        
        if use_tta and self.use_tta:
            predictions = []
            
            augmentations = [
                lambda x: x,
                lambda x: torch.flip(x, [2]),
                lambda x: torch.flip(x, [3]),
                lambda x: torch.flip(x, [4]),
                lambda x: torch.flip(x, [2, 3]),
                lambda x: torch.flip(x, [2, 4]),
                lambda x: torch.flip(x, [3, 4]),
                lambda x: torch.flip(x, [2, 3, 4])
            ]
            
            reverse_augmentations = [
                lambda x: x,
                lambda x: torch.flip(x, [2]),
                lambda x: torch.flip(x, [3]),
                lambda x: torch.flip(x, [4]),
                lambda x: torch.flip(x, [2, 3]),
                lambda x: torch.flip(x, [2, 4]),
                lambda x: torch.flip(x, [3, 4]),
                lambda x: torch.flip(x, [2, 3, 4])
            ]
            
            for aug, rev_aug in zip(augmentations, reverse_augmentations):
                augmented_input = aug(input_tensor)
                
                if self.config.mixed_precision:
                    with autocast():
                        pred = self.model(augmented_input)
                else:
                    pred = self.model(augmented_input)
                
                pred = torch.sigmoid(pred)
                pred = rev_aug(pred)
                predictions.append(pred)
            
            prediction_stack = torch.stack(predictions)
            mean_prediction = prediction_stack.mean(dim=0)
            
            if return_uncertainty:
                uncertainty = prediction_stack.std(dim=0)
                return mean_prediction, uncertainty
            else:
                return mean_prediction
        
        else:
            if self.config.mixed_precision:
                with autocast():
                    prediction = self.model(input_tensor)
            else:
                prediction = self.model(input_tensor)
            
            prediction = torch.sigmoid(prediction)
            
            if return_uncertainty:
                return prediction, None
            else:
                return prediction
    
    def batch_inference(self, case_paths, save_results=True):
        results = []
        
        for case_path in tqdm(case_paths, desc="Processing cases"):
            case_id = Path(case_path).stem if isinstance(case_path, (str, Path)) else case_path.get('case_id', 'unknown')
            
            try:
                start_time = time.time()
                
                if isinstance(case_path, dict):
                    volume_dict = case_path
                else:
                    volume_dict = self._load_case_files(case_path)
                
                prediction, uncertainty = self.predict_single(
                    volume_dict, 
                    use_tta=self.use_tta,
                    return_uncertainty=self.use_uncertainty
                )
                
                prediction_np = prediction.squeeze().cpu().numpy()
                uncertainty_np = uncertainty.squeeze().cpu().numpy() if uncertainty is not None else None
                
                binary_mask = (prediction_np > self.confidence_threshold).astype(np.uint8)
                binary_mask = self.postprocessor.postprocess_mask(binary_mask)
                
                inference_time = time.time() - start_time
                
                result = {
                    'case_id': case_id,
                    'prediction_mask': binary_mask,
                    'probability_map': prediction_np,
                    'uncertainty_map': uncertainty_np,
                    'inference_time': inference_time,
                    'volume_shape': prediction_np.shape,
                    'confidence_threshold': self.confidence_threshold
                }
                
                if save_results:
                    self._save_result(result)
                
                results.append(result)
                
                print(f"✅ {case_id}: {inference_time:.2f}s")
                
            except Exception as e:
                print(f"❌ Error processing {case_id}: {str(e)}")
                continue
        
        return results
    
    def _load_case_files(self, case_path):
        case_path = Path(case_path)
        volume_dict = {}
        
        modalities = ['t1n', 't1c', 't2w', 't2f']
        for modality in modalities:
            matching_files = list(case_path.parent.glob(f"*{modality}*.nii.gz"))
            if matching_files:
                volume_dict[modality] = str(matching_files[0])
        
        return volume_dict
    
    def _save_result(self, result):
        output_dir = Path(self.config.output_dir) / "inference_results"
        output_dir.mkdir(parents=True, exist_ok=True)
        
        mask_path = output_dir / f"{result['case_id']}_segmentation.nii.gz"
        prob_path = output_dir / f"{result['case_id']}_probability.nii.gz"
        
        affine = np.eye(4)
        
        mask_nii = nib.Nifti1Image(result['prediction_mask'].astype(np.float32), affine)
        nib.save(mask_nii, mask_path)
        
        prob_nii = nib.Nifti1Image(result['probability_map'], affine)
        nib.save(prob_nii, prob_path)
        
        if result['uncertainty_map'] is not None:
            uncertainty_path = output_dir / f"{result['case_id']}_uncertainty.nii.gz"
            uncertainty_nii = nib.Nifti1Image(result['uncertainty_map'], affine)
            nib.save(uncertainty_nii, uncertainty_path)

inference_engine = InferenceEngine(model, config, preprocessor, postprocessor, use_tta, use_uncertainty, confidence_threshold)

print(f"\n🚀 INFERENCE ENGINE READY:")
print(f"├── Test-Time Augmentation: {'✅' if use_tta else '❌'}")
print(f"├── Uncertainty Estimation: {'✅' if use_uncertainty else '❌'}")
print(f"├── Confidence Threshold: {confidence_threshold}")
print(f"├── Post-processing: Active")
print(f"└── Batch Processing: Ready")
# Out:
# 🚀 INFERENCE ENGINE READY:
# ├── Test-Time Augmentation: ✅
# ├── Uncertainty Estimation: ✅
# ├── Confidence Threshold: 0.5
# ├── Post-processing: Active
# └── Batch Processing: Ready

# %%
print(f"\n📂 SCANNING FOR TEST CASES...")

test_data_dir = Path(config.data_dir)
test_cases = []

if test_data_dir.exists():
    nii_files = list(test_data_dir.glob("*.nii.gz"))
    
    case_groups = {}
    for file_path in nii_files:
        filename = file_path.stem.replace('.nii', '')
        
        parts = filename.split('-')
        if len(parts) >= 3:
            case_id = '-'.join(parts[:3])
        else:
            case_id = filename.split('_')[0] if '_' in filename else filename
        
        if case_id not in case_groups:
            case_groups[case_id] = {}
        
        modality = None
        for mod in ['t1n', 't1c', 't2w', 't2f', 'seg']:
            if mod in filename.lower():
                modality = mod
                break
        
        if modality and modality != 'seg':
            case_groups[case_id][modality] = str(file_path)
    
    for case_id, modalities in case_groups.items():
        if len(modalities) >= 2:
            modalities['case_id'] = case_id
            test_cases.append(modalities)

print(f"✅ Found {len(test_cases)} test cases:")
for i, case in enumerate(test_cases[:5]):
    modality_count = len([k for k in case.keys() if k != 'case_id'])
    print(f"├── {case['case_id']}: {modality_count} modalities")
if len(test_cases) > 5:
    print(f"└── ... and {len(test_cases) - 5} more cases")

if not test_cases:
    print(f"⚠️  No test cases found. Creating synthetic test case...")
    
    synthetic_volume = torch.randn(4, 64, 64, 64) * 0.1
    
    center = [32, 32, 32]
    for i in range(4):
        for z in range(64):
            for y in range(64):
                for x in range(64):
                    dist = ((z - center[0])**2 + (y - center[1])**2 + (x - center[2])**2) ** 0.5
                    if dist < 25:
                        synthetic_volume[i, z, y, x] += 0.5
    
    tumor_center = [30, 35, 32]
    tumor_size = 8
    for z in range(max(0, tumor_center[0] - tumor_size), min(64, tumor_center[0] + tumor_size)):
        for y in range(max(0, tumor_center[1] - tumor_size), min(64, tumor_center[1] + tumor_size)):
            for x in range(max(0, tumor_center[2] - tumor_size), min(64, tumor_center[2] + tumor_size)):
                dist = ((z - tumor_center[0])**2 + (y - tumor_center[1])**2 + (x - tumor_center[2])**2) ** 0.5
                if dist < tumor_size:
                    for i in range(4):
                        synthetic_volume[i, z, y, x] += 0.4
    
    synthetic_case = {
        'case_id': 'synthetic_test_case',
        'synthetic_volume': synthetic_volume.numpy(),
        'volume_shape': (64, 64, 64)
    }
    test_cases = [synthetic_case]
    print(f"✅ Synthetic test case created")

print(f"\n🎯 INFERENCE CONFIGURATION:")
print(f"├── Test cases: {len(test_cases)}")
print(f"├── Test-Time Augmentation: {'✅' if use_tta else '❌'}")
print(f"├── Uncertainty Estimation: {'✅' if use_uncertainty else '❌'}")
print(f"├── Confidence Threshold: {confidence_threshold}")
print(f"└── Output Directory: {config.output_dir}")
# Out:
# 📂 SCANNING FOR TEST CASES...
# ✅ Found 209 test cases:
# ├── BraTS-GLI-00002: 2 modalities
# ├── BraTS-GLI-00014: 3 modalities
# ├── BraTS-GLI-00016: 3 modalities
# ├── BraTS-GLI-00088: 2 modalities
# ├── BraTS-GLI-00090: 2 modalities
# └── ... and 204 more cases
#
# 🎯 INFERENCE CONFIGURATION:
# ├── Test cases: 209
# ├── Test-Time Augmentation: ✅
# ├── Uncertainty Estimation: ✅
# ├── Confidence Threshold: 0.5
# └── Output Directory: c:\Users\surya\NueroVisionAI\outputs\3d

# %%
inference_results = []
total_inference_time = 0

for idx, test_case in enumerate(test_cases, 1):
    print(f"\n🧠 Processing Case {idx}/{len(test_cases)}: {test_case['case_id']}")
    print("─" * 60)
    try:
        start_time = time.time()
        
        volume_paths = {k: v for k, v in test_case.items() if k != 'case_id'}
        prediction, uncertainty = inference_engine.predict_single(
            volume_paths,
            use_tta=use_tta,
            return_uncertainty=use_uncertainty
        )
        
        prediction_np = prediction.squeeze().cpu().numpy()
        uncertainty_np = uncertainty.squeeze().cpu().numpy() if uncertainty is not None else None
        
        binary_mask = (prediction_np > confidence_threshold).astype(np.uint8)
        binary_mask = postprocessor.postprocess_mask(binary_mask)
        
        inference_time = time.time() - start_time
        total_inference_time += inference_time
        
        result = {
            'case_id': test_case['case_id'],
            'prediction_mask': binary_mask,
            'probability_map': prediction_np,
            'uncertainty_map': uncertainty_np,
            'inference_time': inference_time,
            'volume_shape': prediction_np.shape,
            'confidence_threshold': confidence_threshold
        }
        
        inference_results.append(result)
        
        tumor_volume = np.sum(binary_mask)
        max_prob = np.max(prediction_np)
        
        print(f"✅ Inference completed in {inference_time:.2f}s")
        print(f"├── Tumor detected: {'Yes' if tumor_volume > 0 else 'No'}")
        print(f"├── Tumor volume: {tumor_volume} voxels")
        print(f"└── Max probability: {max_prob:.4f}")
        
    except Exception as e:
        print(f"❌ Error processing {test_case['case_id']}: {e}")
        continue

print(f"\n🎯 INFERENCE SUMMARY:")
print(f"├── Total cases processed: {len(inference_results)}")
print(f"├── Total processing time: {format_time(total_inference_time)}")
print(f"└── Average time per case: {total_inference_time/max(len(inference_results), 1):.2f}s")
# Out:
# 🧠 Processing Case 1/209: BraTS-GLI-00002
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00002: 'preprocessed_data'
#
# 🧠 Processing Case 2/209: BraTS-GLI-00014
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00002: 'preprocessed_data'
#
# 🧠 Processing Case 2/209: BraTS-GLI-00014
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00014: 'preprocessed_data'
#
# 🧠 Processing Case 3/209: BraTS-GLI-00016
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00014: 'preprocessed_data'
#
# 🧠 Processing Case 3/209: BraTS-GLI-00016
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00016: 'preprocessed_data'
#
# 🧠 Processing Case 4/209: BraTS-GLI-00088
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00088: 'preprocessed_data'
#
# 🧠 Processing Case 5/209: BraTS-GLI-00090
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00016: 'preprocessed_data'
#
# 🧠 Processing Case 4/209: BraTS-GLI-00088
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00088: 'preprocessed_data'
#
# 🧠 Processing Case 5/209: BraTS-GLI-00090
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00090: 'preprocessed_data'
#
# 🧠 Processing Case 6/209: BraTS-GLI-00091
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00091: 'preprocessed_data'
#
# 🧠 Processing Case 7/209: BraTS-GLI-00094
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00090: 'preprocessed_data'
#
# 🧠 Processing Case 6/209: BraTS-GLI-00091
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00091: 'preprocessed_data'
#
# 🧠 Processing Case 7/209: BraTS-GLI-00094
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00094: 'preprocessed_data'
#
# 🧠 Processing Case 8/209: BraTS-GLI-00098
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00098: 'preprocessed_data'
#
# 🧠 Processing Case 9/209: BraTS-GLI-00146
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00094: 'preprocessed_data'
#
# 🧠 Processing Case 8/209: BraTS-GLI-00098
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00098: 'preprocessed_data'
#
# 🧠 Processing Case 9/209: BraTS-GLI-00146
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00146: 'preprocessed_data'
#
# 🧠 Processing Case 10/209: BraTS-GLI-00171
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00171: 'preprocessed_data'
#
# 🧠 Processing Case 11/209: BraTS-GLI-00184
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00146: 'preprocessed_data'
#
# 🧠 Processing Case 10/209: BraTS-GLI-00171
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00171: 'preprocessed_data'
#
# 🧠 Processing Case 11/209: BraTS-GLI-00184
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00184: 'preprocessed_data'
#
# 🧠 Processing Case 12/209: BraTS-GLI-00188
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00188: 'preprocessed_data'
#
# 🧠 Processing Case 13/209: BraTS-GLI-00210
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00184: 'preprocessed_data'
#
# 🧠 Processing Case 12/209: BraTS-GLI-00188
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00188: 'preprocessed_data'
#
# 🧠 Processing Case 13/209: BraTS-GLI-00210
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00210: 'preprocessed_data'
#
# 🧠 Processing Case 14/209: BraTS-GLI-00214
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00214: 'preprocessed_data'
#
# 🧠 Processing Case 15/209: BraTS-GLI-00281
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00210: 'preprocessed_data'
#
# 🧠 Processing Case 14/209: BraTS-GLI-00214
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00214: 'preprocessed_data'
#
# 🧠 Processing Case 15/209: BraTS-GLI-00281
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00281: 'preprocessed_data'
#
# 🧠 Processing Case 16/209: BraTS-GLI-00282
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00282: 'preprocessed_data'
#
# 🧠 Processing Case 17/209: BraTS-GLI-00291
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00281: 'preprocessed_data'
#
# 🧠 Processing Case 16/209: BraTS-GLI-00282
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00282: 'preprocessed_data'
#
# 🧠 Processing Case 17/209: BraTS-GLI-00291
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00291: 'preprocessed_data'
#
# 🧠 Processing Case 18/209: BraTS-GLI-00322
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00322: 'preprocessed_data'
#
# 🧠 Processing Case 19/209: BraTS-GLI-00324
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00291: 'preprocessed_data'
#
# 🧠 Processing Case 18/209: BraTS-GLI-00322
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00322: 'preprocessed_data'
#
# 🧠 Processing Case 19/209: BraTS-GLI-00324
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00324: 'preprocessed_data'
#
# 🧠 Processing Case 20/209: BraTS-GLI-00328
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00328: 'preprocessed_data'
#
# 🧠 Processing Case 21/209: BraTS-GLI-00341
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00324: 'preprocessed_data'
#
# 🧠 Processing Case 20/209: BraTS-GLI-00328
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00328: 'preprocessed_data'
#
# 🧠 Processing Case 21/209: BraTS-GLI-00341
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00341: 'preprocessed_data'
#
# 🧠 Processing Case 22/209: BraTS-GLI-00347
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00347: 'preprocessed_data'
# ❌ Error processing BraTS-GLI-00341: 'preprocessed_data'
#
# 🧠 Processing Case 22/209: BraTS-GLI-00347
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00347: 'preprocessed_data'
#
# 🧠 Processing Case 23/209: BraTS-GLI-00373
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00373: 'preprocessed_data'
#
# 🧠 Processing Case 24/209: BraTS-GLI-00386
# ────────────────────────────────────────────────────────────
#
# 🧠 Processing Case 23/209: BraTS-GLI-00373
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00373: 'preprocessed_data'
#
# 🧠 Processing Case 24/209: BraTS-GLI-00386
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00386: 'preprocessed_data'
#
# 🧠 Processing Case 25/209: BraTS-GLI-00421
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00421: 'preprocessed_data'
#
# 🧠 Processing Case 26/209: BraTS-GLI-00446
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00386: 'preprocessed_data'
#
# 🧠 Processing Case 25/209: BraTS-GLI-00421
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00421: 'preprocessed_data'
#
# 🧠 Processing Case 26/209: BraTS-GLI-00446
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00446: 'preprocessed_data'
#
# 🧠 Processing Case 27/209: BraTS-GLI-00454
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00454: 'preprocessed_data'
#
# 🧠 Processing Case 28/209: BraTS-GLI-00456
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00446: 'preprocessed_data'
#
# 🧠 Processing Case 27/209: BraTS-GLI-00454
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00454: 'preprocessed_data'
#
# 🧠 Processing Case 28/209: BraTS-GLI-00456
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00456: 'preprocessed_data'
#
# 🧠 Processing Case 29/209: BraTS-GLI-00462
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00462: 'preprocessed_data'
#
# 🧠 Processing Case 30/209: BraTS-GLI-00464
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00456: 'preprocessed_data'
#
# 🧠 Processing Case 29/209: BraTS-GLI-00462
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00462: 'preprocessed_data'
#
# 🧠 Processing Case 30/209: BraTS-GLI-00464
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00464: 'preprocessed_data'
#
# 🧠 Processing Case 31/209: BraTS-GLI-00474
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00474: 'preprocessed_data'
#
# 🧠 Processing Case 32/209: BraTS-GLI-00478
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00464: 'preprocessed_data'
#
# 🧠 Processing Case 31/209: BraTS-GLI-00474
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00474: 'preprocessed_data'
#
# 🧠 Processing Case 32/209: BraTS-GLI-00478
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00478: 'preprocessed_data'
#
# 🧠 Processing Case 33/209: BraTS-GLI-00485
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00485: 'preprocessed_data'
#
# 🧠 Processing Case 34/209: BraTS-GLI-00489
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00478: 'preprocessed_data'
#
# 🧠 Processing Case 33/209: BraTS-GLI-00485
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00485: 'preprocessed_data'
#
# 🧠 Processing Case 34/209: BraTS-GLI-00489
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00489: 'preprocessed_data'
#
# 🧠 Processing Case 35/209: BraTS-GLI-00511
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00489: 'preprocessed_data'
#
# 🧠 Processing Case 35/209: BraTS-GLI-00511
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00511: 'preprocessed_data'
#
# 🧠 Processing Case 36/209: BraTS-GLI-00517
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00517: 'preprocessed_data'
#
# 🧠 Processing Case 37/209: BraTS-GLI-00518
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00511: 'preprocessed_data'
#
# 🧠 Processing Case 36/209: BraTS-GLI-00517
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00517: 'preprocessed_data'
#
# 🧠 Processing Case 37/209: BraTS-GLI-00518
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00518: 'preprocessed_data'
#
# 🧠 Processing Case 38/209: BraTS-GLI-00520
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00520: 'preprocessed_data'
#
# 🧠 Processing Case 39/209: BraTS-GLI-00526
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00518: 'preprocessed_data'
#
# 🧠 Processing Case 38/209: BraTS-GLI-00520
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00520: 'preprocessed_data'
#
# 🧠 Processing Case 39/209: BraTS-GLI-00526
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00526: 'preprocessed_data'
#
# 🧠 Processing Case 40/209: BraTS-GLI-00529
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00529: 'preprocessed_data'
#
# 🧠 Processing Case 41/209: BraTS-GLI-00543
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00526: 'preprocessed_data'
#
# 🧠 Processing Case 40/209: BraTS-GLI-00529
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00529: 'preprocessed_data'
#
# 🧠 Processing Case 41/209: BraTS-GLI-00543
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00543: 'preprocessed_data'
#
# 🧠 Processing Case 42/209: BraTS-GLI-00549
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00549: 'preprocessed_data'
#
# 🧠 Processing Case 43/209: BraTS-GLI-00555
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00543: 'preprocessed_data'
#
# 🧠 Processing Case 42/209: BraTS-GLI-00549
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00549: 'preprocessed_data'
#
# 🧠 Processing Case 43/209: BraTS-GLI-00555
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00555: 'preprocessed_data'
#
# 🧠 Processing Case 44/209: BraTS-GLI-00559
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00559: 'preprocessed_data'
#
# 🧠 Processing Case 45/209: BraTS-GLI-00563
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00555: 'preprocessed_data'
#
# 🧠 Processing Case 44/209: BraTS-GLI-00559
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00559: 'preprocessed_data'
#
# 🧠 Processing Case 45/209: BraTS-GLI-00563
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00563: 'preprocessed_data'
#
# 🧠 Processing Case 46/209: BraTS-GLI-00575
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00575: 'preprocessed_data'
#
# 🧠 Processing Case 47/209: BraTS-GLI-00576
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00563: 'preprocessed_data'
#
# 🧠 Processing Case 46/209: BraTS-GLI-00575
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00575: 'preprocessed_data'
#
# 🧠 Processing Case 47/209: BraTS-GLI-00576
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00576: 'preprocessed_data'
#
# 🧠 Processing Case 48/209: BraTS-GLI-00611
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00611: 'preprocessed_data'
#
# 🧠 Processing Case 49/209: BraTS-GLI-00645
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00576: 'preprocessed_data'
#
# 🧠 Processing Case 48/209: BraTS-GLI-00611
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00611: 'preprocessed_data'
#
# 🧠 Processing Case 49/209: BraTS-GLI-00645
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00645: 'preprocessed_data'
#
# 🧠 Processing Case 50/209: BraTS-GLI-00655
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00655: 'preprocessed_data'
#
# 🧠 Processing Case 51/209: BraTS-GLI-00659
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00645: 'preprocessed_data'
#
# 🧠 Processing Case 50/209: BraTS-GLI-00655
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00655: 'preprocessed_data'
#
# 🧠 Processing Case 51/209: BraTS-GLI-00659
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00659: 'preprocessed_data'
#
# 🧠 Processing Case 52/209: BraTS-GLI-00663
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00663: 'preprocessed_data'
#
# 🧠 Processing Case 53/209: BraTS-GLI-00690
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00659: 'preprocessed_data'
#
# 🧠 Processing Case 52/209: BraTS-GLI-00663
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00663: 'preprocessed_data'
#
# 🧠 Processing Case 53/209: BraTS-GLI-00690
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00690: 'preprocessed_data'
#
# 🧠 Processing Case 54/209: BraTS-GLI-00699
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00699: 'preprocessed_data'
#
# 🧠 Processing Case 55/209: BraTS-GLI-00703
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00690: 'preprocessed_data'
#
# 🧠 Processing Case 54/209: BraTS-GLI-00699
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00699: 'preprocessed_data'
#
# 🧠 Processing Case 55/209: BraTS-GLI-00703
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00703: 'preprocessed_data'
#
# 🧠 Processing Case 56/209: BraTS-GLI-00708
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00708: 'preprocessed_data'
#
# 🧠 Processing Case 57/209: BraTS-GLI-00712
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00703: 'preprocessed_data'
#
# 🧠 Processing Case 56/209: BraTS-GLI-00708
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00708: 'preprocessed_data'
#
# 🧠 Processing Case 57/209: BraTS-GLI-00712
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00712: 'preprocessed_data'
#
# 🧠 Processing Case 58/209: BraTS-GLI-00715
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00715: 'preprocessed_data'
#
# 🧠 Processing Case 59/209: BraTS-GLI-00718
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00712: 'preprocessed_data'
#
# 🧠 Processing Case 58/209: BraTS-GLI-00715
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00715: 'preprocessed_data'
#
# 🧠 Processing Case 59/209: BraTS-GLI-00718
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00718: 'preprocessed_data'
#
# 🧠 Processing Case 60/209: BraTS-GLI-00724
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00724: 'preprocessed_data'
#
# 🧠 Processing Case 61/209: BraTS-GLI-00746
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00718: 'preprocessed_data'
#
# 🧠 Processing Case 60/209: BraTS-GLI-00724
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00724: 'preprocessed_data'
#
# 🧠 Processing Case 61/209: BraTS-GLI-00746
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00746: 'preprocessed_data'
#
# 🧠 Processing Case 62/209: BraTS-GLI-00757
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00757: 'preprocessed_data'
#
# 🧠 Processing Case 63/209: BraTS-GLI-00760
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00746: 'preprocessed_data'
#
# 🧠 Processing Case 62/209: BraTS-GLI-00757
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00757: 'preprocessed_data'
#
# 🧠 Processing Case 63/209: BraTS-GLI-00760
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00760: 'preprocessed_data'
#
# 🧠 Processing Case 64/209: BraTS-GLI-00764
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00764: 'preprocessed_data'
#
# 🧠 Processing Case 65/209: BraTS-GLI-00772
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00760: 'preprocessed_data'
#
# 🧠 Processing Case 64/209: BraTS-GLI-00764
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00764: 'preprocessed_data'
#
# 🧠 Processing Case 65/209: BraTS-GLI-00772
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00772: 'preprocessed_data'
#
# 🧠 Processing Case 66/209: BraTS-GLI-00774
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00774: 'preprocessed_data'
#
# 🧠 Processing Case 67/209: BraTS-GLI-00806
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00772: 'preprocessed_data'
#
# 🧠 Processing Case 66/209: BraTS-GLI-00774
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00774: 'preprocessed_data'
#
# 🧠 Processing Case 67/209: BraTS-GLI-00806
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00806: 'preprocessed_data'
#
# 🧠 Processing Case 68/209: BraTS-GLI-00823
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00823: 'preprocessed_data'
#
# 🧠 Processing Case 69/209: BraTS-GLI-00839
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00806: 'preprocessed_data'
#
# 🧠 Processing Case 68/209: BraTS-GLI-00823
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00823: 'preprocessed_data'
#
# 🧠 Processing Case 69/209: BraTS-GLI-00839
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00839: 'preprocessed_data'
#
# 🧠 Processing Case 70/209: BraTS-GLI-01001
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01001: 'preprocessed_data'
#
# 🧠 Processing Case 71/209: BraTS-GLI-01006
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-00839: 'preprocessed_data'
#
# 🧠 Processing Case 70/209: BraTS-GLI-01001
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01001: 'preprocessed_data'
#
# 🧠 Processing Case 71/209: BraTS-GLI-01006
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01006: 'preprocessed_data'
#
# 🧠 Processing Case 72/209: BraTS-GLI-01016
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01016: 'preprocessed_data'
#
# 🧠 Processing Case 73/209: BraTS-GLI-01028
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01006: 'preprocessed_data'
#
# 🧠 Processing Case 72/209: BraTS-GLI-01016
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01016: 'preprocessed_data'
#
# 🧠 Processing Case 73/209: BraTS-GLI-01028
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01028: 'preprocessed_data'
#
# 🧠 Processing Case 74/209: BraTS-GLI-01029
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01029: 'preprocessed_data'
#
# 🧠 Processing Case 75/209: BraTS-GLI-01034
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01028: 'preprocessed_data'
#
# 🧠 Processing Case 74/209: BraTS-GLI-01029
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01029: 'preprocessed_data'
#
# 🧠 Processing Case 75/209: BraTS-GLI-01034
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01034: 'preprocessed_data'
#
# 🧠 Processing Case 76/209: BraTS-GLI-01037
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01037: 'preprocessed_data'
#
# 🧠 Processing Case 77/209: BraTS-GLI-01056
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01034: 'preprocessed_data'
#
# 🧠 Processing Case 76/209: BraTS-GLI-01037
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01037: 'preprocessed_data'
#
# 🧠 Processing Case 77/209: BraTS-GLI-01056
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01056: 'preprocessed_data'
#
# 🧠 Processing Case 78/209: BraTS-GLI-01108
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01108: 'preprocessed_data'
#
# 🧠 Processing Case 79/209: BraTS-GLI-01116
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01056: 'preprocessed_data'
#
# 🧠 Processing Case 78/209: BraTS-GLI-01108
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01108: 'preprocessed_data'
#
# 🧠 Processing Case 79/209: BraTS-GLI-01116
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01116: 'preprocessed_data'
#
# 🧠 Processing Case 80/209: BraTS-GLI-01120
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01120: 'preprocessed_data'
#
# 🧠 Processing Case 81/209: BraTS-GLI-01136
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01116: 'preprocessed_data'
#
# 🧠 Processing Case 80/209: BraTS-GLI-01120
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01120: 'preprocessed_data'
#
# 🧠 Processing Case 81/209: BraTS-GLI-01136
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01136: 'preprocessed_data'
#
# 🧠 Processing Case 82/209: BraTS-GLI-01143
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01143: 'preprocessed_data'
#
# 🧠 Processing Case 83/209: BraTS-GLI-01162
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01136: 'preprocessed_data'
#
# 🧠 Processing Case 82/209: BraTS-GLI-01143
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01143: 'preprocessed_data'
#
# 🧠 Processing Case 83/209: BraTS-GLI-01162
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01162: 'preprocessed_data'
#
# 🧠 Processing Case 84/209: BraTS-GLI-01180
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01180: 'preprocessed_data'
#
# 🧠 Processing Case 85/209: BraTS-GLI-01198
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01162: 'preprocessed_data'
#
# 🧠 Processing Case 84/209: BraTS-GLI-01180
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01180: 'preprocessed_data'
#
# 🧠 Processing Case 85/209: BraTS-GLI-01198
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01198: 'preprocessed_data'
#
# 🧠 Processing Case 86/209: BraTS-GLI-01211
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01211: 'preprocessed_data'
#
# 🧠 Processing Case 87/209: BraTS-GLI-01213
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01198: 'preprocessed_data'
#
# 🧠 Processing Case 86/209: BraTS-GLI-01211
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01211: 'preprocessed_data'
#
# 🧠 Processing Case 87/209: BraTS-GLI-01213
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01213: 'preprocessed_data'
#
# 🧠 Processing Case 88/209: BraTS-GLI-01225
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01225: 'preprocessed_data'
#
# 🧠 Processing Case 89/209: BraTS-GLI-01244
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01213: 'preprocessed_data'
#
# 🧠 Processing Case 88/209: BraTS-GLI-01225
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01225: 'preprocessed_data'
#
# 🧠 Processing Case 89/209: BraTS-GLI-01244
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01244: 'preprocessed_data'
#
# 🧠 Processing Case 90/209: BraTS-GLI-01256
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01256: 'preprocessed_data'
#
# 🧠 Processing Case 91/209: BraTS-GLI-01283
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01244: 'preprocessed_data'
#
# 🧠 Processing Case 90/209: BraTS-GLI-01256
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01256: 'preprocessed_data'
#
# 🧠 Processing Case 91/209: BraTS-GLI-01283
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01283: 'preprocessed_data'
#
# 🧠 Processing Case 92/209: BraTS-GLI-01304
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01304: 'preprocessed_data'
#
# 🧠 Processing Case 93/209: BraTS-GLI-01308
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01283: 'preprocessed_data'
#
# 🧠 Processing Case 92/209: BraTS-GLI-01304
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01304: 'preprocessed_data'
#
# 🧠 Processing Case 93/209: BraTS-GLI-01308
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01308: 'preprocessed_data'
#
# 🧠 Processing Case 94/209: BraTS-GLI-01310
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01310: 'preprocessed_data'
#
# 🧠 Processing Case 95/209: BraTS-GLI-01315
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01308: 'preprocessed_data'
#
# 🧠 Processing Case 94/209: BraTS-GLI-01310
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01310: 'preprocessed_data'
#
# 🧠 Processing Case 95/209: BraTS-GLI-01315
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01315: 'preprocessed_data'
#
# 🧠 Processing Case 96/209: BraTS-GLI-01322
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01322: 'preprocessed_data'
#
# 🧠 Processing Case 97/209: BraTS-GLI-01329
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01315: 'preprocessed_data'
#
# 🧠 Processing Case 96/209: BraTS-GLI-01322
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01322: 'preprocessed_data'
#
# 🧠 Processing Case 97/209: BraTS-GLI-01329
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01329: 'preprocessed_data'
#
# 🧠 Processing Case 98/209: BraTS-GLI-01394
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01394: 'preprocessed_data'
#
# 🧠 Processing Case 99/209: BraTS-GLI-01396
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01329: 'preprocessed_data'
#
# 🧠 Processing Case 98/209: BraTS-GLI-01394
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01394: 'preprocessed_data'
#
# 🧠 Processing Case 99/209: BraTS-GLI-01396
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01396: 'preprocessed_data'
#
# 🧠 Processing Case 100/209: BraTS-GLI-01399
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01399: 'preprocessed_data'
#
# 🧠 Processing Case 101/209: BraTS-GLI-01401
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01396: 'preprocessed_data'
#
# 🧠 Processing Case 100/209: BraTS-GLI-01399
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01399: 'preprocessed_data'
#
# 🧠 Processing Case 101/209: BraTS-GLI-01401
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01401: 'preprocessed_data'
#
# 🧠 Processing Case 102/209: BraTS-GLI-01438
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01438: 'preprocessed_data'
#
# 🧠 Processing Case 103/209: BraTS-GLI-01491
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01401: 'preprocessed_data'
#
# 🧠 Processing Case 102/209: BraTS-GLI-01438
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01438: 'preprocessed_data'
#
# 🧠 Processing Case 103/209: BraTS-GLI-01491
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01491: 'preprocessed_data'
#
# 🧠 Processing Case 104/209: BraTS-GLI-01493
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01493: 'preprocessed_data'
#
# 🧠 Processing Case 105/209: BraTS-GLI-01505
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01491: 'preprocessed_data'
#
# 🧠 Processing Case 104/209: BraTS-GLI-01493
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01493: 'preprocessed_data'
#
# 🧠 Processing Case 105/209: BraTS-GLI-01505
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01505: 'preprocessed_data'
#
# 🧠 Processing Case 106/209: BraTS-GLI-01507
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01507: 'preprocessed_data'
#
# 🧠 Processing Case 107/209: BraTS-GLI-01527
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01505: 'preprocessed_data'
#
# 🧠 Processing Case 106/209: BraTS-GLI-01507
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01507: 'preprocessed_data'
#
# 🧠 Processing Case 107/209: BraTS-GLI-01527
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01527: 'preprocessed_data'
#
# 🧠 Processing Case 108/209: BraTS-GLI-01665
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01665: 'preprocessed_data'
#
# 🧠 Processing Case 109/209: BraTS-GLI-01676
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01527: 'preprocessed_data'
#
# 🧠 Processing Case 108/209: BraTS-GLI-01665
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01665: 'preprocessed_data'
#
# 🧠 Processing Case 109/209: BraTS-GLI-01676
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01676: 'preprocessed_data'
#
# 🧠 Processing Case 110/209: BraTS-GLI-01693
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01693: 'preprocessed_data'
#
# 🧠 Processing Case 111/209: BraTS-GLI-01708
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01676: 'preprocessed_data'
#
# 🧠 Processing Case 110/209: BraTS-GLI-01693
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01693: 'preprocessed_data'
#
# 🧠 Processing Case 111/209: BraTS-GLI-01708
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01708: 'preprocessed_data'
#
# 🧠 Processing Case 112/209: BraTS-GLI-01730
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01730: 'preprocessed_data'
#
# 🧠 Processing Case 113/209: BraTS-GLI-01758
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01708: 'preprocessed_data'
#
# 🧠 Processing Case 112/209: BraTS-GLI-01730
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01730: 'preprocessed_data'
#
# 🧠 Processing Case 113/209: BraTS-GLI-01758
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01758: 'preprocessed_data'
#
# 🧠 Processing Case 114/209: BraTS-GLI-01763
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01763: 'preprocessed_data'
#
# 🧠 Processing Case 115/209: BraTS-GLI-01770
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01758: 'preprocessed_data'
#
# 🧠 Processing Case 114/209: BraTS-GLI-01763
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01763: 'preprocessed_data'
#
# 🧠 Processing Case 115/209: BraTS-GLI-01770
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01770: 'preprocessed_data'
#
# 🧠 Processing Case 116/209: BraTS-MEN-00041
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00041: 'preprocessed_data'
#
# 🧠 Processing Case 117/209: BraTS-MEN-00042
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-GLI-01770: 'preprocessed_data'
#
# 🧠 Processing Case 116/209: BraTS-MEN-00041
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00041: 'preprocessed_data'
#
# 🧠 Processing Case 117/209: BraTS-MEN-00042
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00042: 'preprocessed_data'
#
# 🧠 Processing Case 118/209: BraTS-MEN-00065
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00065: 'preprocessed_data'
#
# 🧠 Processing Case 119/209: BraTS-MEN-00074
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00042: 'preprocessed_data'
#
# 🧠 Processing Case 118/209: BraTS-MEN-00065
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00065: 'preprocessed_data'
#
# 🧠 Processing Case 119/209: BraTS-MEN-00074
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00074: 'preprocessed_data'
#
# 🧠 Processing Case 120/209: BraTS-MEN-00075
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00075: 'preprocessed_data'
#
# 🧠 Processing Case 121/209: BraTS-MEN-00085
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00074: 'preprocessed_data'
#
# 🧠 Processing Case 120/209: BraTS-MEN-00075
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00075: 'preprocessed_data'
#
# 🧠 Processing Case 121/209: BraTS-MEN-00085
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00085: 'preprocessed_data'
#
# 🧠 Processing Case 122/209: BraTS-MEN-00090
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00090: 'preprocessed_data'
#
# 🧠 Processing Case 123/209: BraTS-MEN-00110
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00085: 'preprocessed_data'
#
# 🧠 Processing Case 122/209: BraTS-MEN-00090
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00090: 'preprocessed_data'
#
# 🧠 Processing Case 123/209: BraTS-MEN-00110
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00110: 'preprocessed_data'
#
# 🧠 Processing Case 124/209: BraTS-MEN-00124
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00124: 'preprocessed_data'
#
# 🧠 Processing Case 125/209: BraTS-MEN-00138
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00110: 'preprocessed_data'
#
# 🧠 Processing Case 124/209: BraTS-MEN-00124
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00124: 'preprocessed_data'
#
# 🧠 Processing Case 125/209: BraTS-MEN-00138
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00138: 'preprocessed_data'
#
# 🧠 Processing Case 126/209: BraTS-MEN-00167
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00138: 'preprocessed_data'
#
# 🧠 Processing Case 126/209: BraTS-MEN-00167
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00167: 'preprocessed_data'
#
# 🧠 Processing Case 127/209: BraTS-MEN-00168
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00168: 'preprocessed_data'
#
# 🧠 Processing Case 128/209: BraTS-MEN-00187
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00167: 'preprocessed_data'
#
# 🧠 Processing Case 127/209: BraTS-MEN-00168
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00168: 'preprocessed_data'
#
# 🧠 Processing Case 128/209: BraTS-MEN-00187
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00187: 'preprocessed_data'
#
# 🧠 Processing Case 129/209: BraTS-MEN-00198
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00198: 'preprocessed_data'
#
# 🧠 Processing Case 130/209: BraTS-MEN-00210
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00187: 'preprocessed_data'
#
# 🧠 Processing Case 129/209: BraTS-MEN-00198
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00198: 'preprocessed_data'
#
# 🧠 Processing Case 130/209: BraTS-MEN-00210
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00210: 'preprocessed_data'
#
# 🧠 Processing Case 131/209: BraTS-MEN-00212
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00212: 'preprocessed_data'
#
# 🧠 Processing Case 132/209: BraTS-MEN-00229
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00210: 'preprocessed_data'
#
# 🧠 Processing Case 131/209: BraTS-MEN-00212
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00212: 'preprocessed_data'
#
# 🧠 Processing Case 132/209: BraTS-MEN-00229
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00229: 'preprocessed_data'
#
# 🧠 Processing Case 133/209: BraTS-MEN-00237
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00237: 'preprocessed_data'
#
# 🧠 Processing Case 134/209: BraTS-MEN-00246
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00229: 'preprocessed_data'
#
# 🧠 Processing Case 133/209: BraTS-MEN-00237
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00237: 'preprocessed_data'
#
# 🧠 Processing Case 134/209: BraTS-MEN-00246
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00246: 'preprocessed_data'
#
# 🧠 Processing Case 135/209: BraTS-MEN-00252
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00252: 'preprocessed_data'
#
# 🧠 Processing Case 136/209: BraTS-MEN-00256
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00246: 'preprocessed_data'
#
# 🧠 Processing Case 135/209: BraTS-MEN-00252
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00252: 'preprocessed_data'
#
# 🧠 Processing Case 136/209: BraTS-MEN-00256
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00256: 'preprocessed_data'
#
# 🧠 Processing Case 137/209: BraTS-MEN-00278
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00278: 'preprocessed_data'
#
# 🧠 Processing Case 138/209: BraTS-MEN-00279
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00256: 'preprocessed_data'
#
# 🧠 Processing Case 137/209: BraTS-MEN-00278
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00278: 'preprocessed_data'
#
# 🧠 Processing Case 138/209: BraTS-MEN-00279
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00279: 'preprocessed_data'
#
# 🧠 Processing Case 139/209: BraTS-MEN-00304
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00279: 'preprocessed_data'
#
# 🧠 Processing Case 139/209: BraTS-MEN-00304
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00304: 'preprocessed_data'
#
# 🧠 Processing Case 140/209: BraTS-MEN-00326
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00326: 'preprocessed_data'
#
# 🧠 Processing Case 141/209: BraTS-MEN-00352
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00304: 'preprocessed_data'
#
# 🧠 Processing Case 140/209: BraTS-MEN-00326
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00326: 'preprocessed_data'
#
# 🧠 Processing Case 141/209: BraTS-MEN-00352
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00352: 'preprocessed_data'
#
# 🧠 Processing Case 142/209: BraTS-MEN-00362
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00352: 'preprocessed_data'
#
# 🧠 Processing Case 142/209: BraTS-MEN-00362
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00362: 'preprocessed_data'
#
# 🧠 Processing Case 143/209: BraTS-MEN-00385
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00385: 'preprocessed_data'
#
# 🧠 Processing Case 144/209: BraTS-MEN-00435
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00362: 'preprocessed_data'
#
# 🧠 Processing Case 143/209: BraTS-MEN-00385
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00385: 'preprocessed_data'
#
# 🧠 Processing Case 144/209: BraTS-MEN-00435
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00435: 'preprocessed_data'
#
# 🧠 Processing Case 145/209: BraTS-MEN-00437
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00437: 'preprocessed_data'
#
# 🧠 Processing Case 146/209: BraTS-MEN-00471
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00435: 'preprocessed_data'
#
# 🧠 Processing Case 145/209: BraTS-MEN-00437
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00437: 'preprocessed_data'
#
# 🧠 Processing Case 146/209: BraTS-MEN-00471
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00471: 'preprocessed_data'
#
# 🧠 Processing Case 147/209: BraTS-MEN-00482
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00482: 'preprocessed_data'
#
# 🧠 Processing Case 148/209: BraTS-MEN-00487
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00471: 'preprocessed_data'
#
# 🧠 Processing Case 147/209: BraTS-MEN-00482
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00482: 'preprocessed_data'
#
# 🧠 Processing Case 148/209: BraTS-MEN-00487
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00487: 'preprocessed_data'
#
# 🧠 Processing Case 149/209: BraTS-MEN-00491
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00491: 'preprocessed_data'
#
# 🧠 Processing Case 150/209: BraTS-MEN-00499
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00487: 'preprocessed_data'
#
# 🧠 Processing Case 149/209: BraTS-MEN-00491
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00491: 'preprocessed_data'
#
# 🧠 Processing Case 150/209: BraTS-MEN-00499
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00499: 'preprocessed_data'
#
# 🧠 Processing Case 151/209: BraTS-MEN-00510
# ...
# ❌ Error processing BraTS-MEN-00689: 'preprocessed_data'
#
# 🧠 Processing Case 161/209: BraTS-MEN-00698
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00698: 'preprocessed_data'
#
# 🧠 Processing Case 162/209: BraTS-MEN-00717
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00698: 'preprocessed_data'
#
# 🧠 Processing Case 162/209: BraTS-MEN-00717
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00717: 'preprocessed_data'
#
# 🧠 Processing Case 163/209: BraTS-MEN-00729
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00729: 'preprocessed_data'
#
# 🧠 Processing Case 164/209: BraTS-MEN-00747
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00717: 'preprocessed_data'
#
# 🧠 Processing Case 163/209: BraTS-MEN-00729
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00729: 'preprocessed_data'
#
# 🧠 Processing Case 164/209: BraTS-MEN-00747
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00747: 'preprocessed_data'
#
# 🧠 Processing Case 165/209: BraTS-MEN-00770
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00770: 'preprocessed_data'
#
# 🧠 Processing Case 166/209: BraTS-MEN-00774
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00747: 'preprocessed_data'
#
# 🧠 Processing Case 165/209: BraTS-MEN-00770
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00770: 'preprocessed_data'
#
# 🧠 Processing Case 166/209: BraTS-MEN-00774
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00774: 'preprocessed_data'
#
# 🧠 Processing Case 167/209: BraTS-MEN-00786
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00786: 'preprocessed_data'
#
# 🧠 Processing Case 168/209: BraTS-MEN-00818
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00774: 'preprocessed_data'
#
# 🧠 Processing Case 167/209: BraTS-MEN-00786
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00786: 'preprocessed_data'
#
# 🧠 Processing Case 168/209: BraTS-MEN-00818
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00818: 'preprocessed_data'
#
# 🧠 Processing Case 169/209: BraTS-MEN-00821
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00821: 'preprocessed_data'
#
# 🧠 Processing Case 170/209: BraTS-MEN-00860
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00818: 'preprocessed_data'
#
# 🧠 Processing Case 169/209: BraTS-MEN-00821
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00821: 'preprocessed_data'
#
# 🧠 Processing Case 170/209: BraTS-MEN-00860
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00860: 'preprocessed_data'
#
# 🧠 Processing Case 171/209: BraTS-MEN-00899
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00899: 'preprocessed_data'
#
# 🧠 Processing Case 172/209: BraTS-MEN-00906
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00860: 'preprocessed_data'
#
# 🧠 Processing Case 171/209: BraTS-MEN-00899
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00899: 'preprocessed_data'
#
# 🧠 Processing Case 172/209: BraTS-MEN-00906
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00906: 'preprocessed_data'
#
# 🧠 Processing Case 173/209: BraTS-MEN-00918
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00918: 'preprocessed_data'
#
# 🧠 Processing Case 174/209: BraTS-MEN-00927
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00906: 'preprocessed_data'
#
# 🧠 Processing Case 173/209: BraTS-MEN-00918
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00918: 'preprocessed_data'
#
# 🧠 Processing Case 174/209: BraTS-MEN-00927
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00927: 'preprocessed_data'
#
# 🧠 Processing Case 175/209: BraTS-MEN-00932
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00927: 'preprocessed_data'
#
# 🧠 Processing Case 175/209: BraTS-MEN-00932
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00932: 'preprocessed_data'
#
# 🧠 Processing Case 176/209: BraTS-MEN-00937
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00932: 'preprocessed_data'
#
# 🧠 Processing Case 176/209: BraTS-MEN-00937
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00937: 'preprocessed_data'
#
# 🧠 Processing Case 177/209: BraTS-MEN-00983
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00983: 'preprocessed_data'
#
# 🧠 Processing Case 178/209: BraTS-MEN-01007
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00937: 'preprocessed_data'
#
# 🧠 Processing Case 177/209: BraTS-MEN-00983
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-00983: 'preprocessed_data'
#
# 🧠 Processing Case 178/209: BraTS-MEN-01007
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01007: 'preprocessed_data'
#
# 🧠 Processing Case 179/209: BraTS-MEN-01008
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01008: 'preprocessed_data'
#
# 🧠 Processing Case 180/209: BraTS-MEN-01014
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01007: 'preprocessed_data'
#
# 🧠 Processing Case 179/209: BraTS-MEN-01008
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01008: 'preprocessed_data'
#
# 🧠 Processing Case 180/209: BraTS-MEN-01014
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01014: 'preprocessed_data'
#
# 🧠 Processing Case 181/209: BraTS-MEN-01039
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01039: 'preprocessed_data'
#
# 🧠 Processing Case 182/209: BraTS-MEN-01066
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01014: 'preprocessed_data'
#
# 🧠 Processing Case 181/209: BraTS-MEN-01039
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01039: 'preprocessed_data'
#
# 🧠 Processing Case 182/209: BraTS-MEN-01066
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01066: 'preprocessed_data'
#
# 🧠 Processing Case 183/209: BraTS-MEN-01072
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01066: 'preprocessed_data'
#
# 🧠 Processing Case 183/209: BraTS-MEN-01072
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01072: 'preprocessed_data'
#
# 🧠 Processing Case 184/209: BraTS-MEN-01103
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01103: 'preprocessed_data'
#
# 🧠 Processing Case 185/209: BraTS-MEN-01136
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01072: 'preprocessed_data'
#
# 🧠 Processing Case 184/209: BraTS-MEN-01103
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01103: 'preprocessed_data'
#
# 🧠 Processing Case 185/209: BraTS-MEN-01136
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01136: 'preprocessed_data'
#
# 🧠 Processing Case 186/209: BraTS-MEN-01152
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01152: 'preprocessed_data'
#
# 🧠 Processing Case 187/209: BraTS-MEN-01192
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01136: 'preprocessed_data'
#
# 🧠 Processing Case 186/209: BraTS-MEN-01152
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01152: 'preprocessed_data'
#
# 🧠 Processing Case 187/209: BraTS-MEN-01192
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01192: 'preprocessed_data'
#
# 🧠 Processing Case 188/209: BraTS-MEN-01208
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01192: 'preprocessed_data'
#
# 🧠 Processing Case 188/209: BraTS-MEN-01208
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01208: 'preprocessed_data'
#
# 🧠 Processing Case 189/209: BraTS-MEN-01224
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01224: 'preprocessed_data'
#
# 🧠 Processing Case 190/209: BraTS-MEN-01229
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01208: 'preprocessed_data'
#
# 🧠 Processing Case 189/209: BraTS-MEN-01224
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01224: 'preprocessed_data'
#
# 🧠 Processing Case 190/209: BraTS-MEN-01229
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01229: 'preprocessed_data'
#
# 🧠 Processing Case 191/209: BraTS-MEN-01231
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01231: 'preprocessed_data'
#
# 🧠 Processing Case 192/209: BraTS-MEN-01242
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01229: 'preprocessed_data'
#
# 🧠 Processing Case 191/209: BraTS-MEN-01231
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01231: 'preprocessed_data'
#
# 🧠 Processing Case 192/209: BraTS-MEN-01242
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01242: 'preprocessed_data'
#
# 🧠 Processing Case 193/209: BraTS-MEN-01243
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01243: 'preprocessed_data'
#
# 🧠 Processing Case 194/209: BraTS-MEN-01253
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01242: 'preprocessed_data'
#
# 🧠 Processing Case 193/209: BraTS-MEN-01243
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01243: 'preprocessed_data'
#
# 🧠 Processing Case 194/209: BraTS-MEN-01253
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01253: 'preprocessed_data'
#
# 🧠 Processing Case 195/209: BraTS-MEN-01279
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01279: 'preprocessed_data'
#
# 🧠 Processing Case 196/209: BraTS-MEN-01290
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01253: 'preprocessed_data'
#
# 🧠 Processing Case 195/209: BraTS-MEN-01279
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01279: 'preprocessed_data'
#
# 🧠 Processing Case 196/209: BraTS-MEN-01290
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01290: 'preprocessed_data'
#
# 🧠 Processing Case 197/209: BraTS-MEN-01298
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01298: 'preprocessed_data'
#
# 🧠 Processing Case 198/209: BraTS-MEN-01355
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01290: 'preprocessed_data'
#
# 🧠 Processing Case 197/209: BraTS-MEN-01298
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01298: 'preprocessed_data'
#
# 🧠 Processing Case 198/209: BraTS-MEN-01355
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01355: 'preprocessed_data'
#
# 🧠 Processing Case 199/209: BraTS-MEN-01383
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01355: 'preprocessed_data'
#
# 🧠 Processing Case 199/209: BraTS-MEN-01383
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01383: 'preprocessed_data'
#
# 🧠 Processing Case 200/209: BraTS-MEN-01399
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01399: 'preprocessed_data'
#
# 🧠 Processing Case 201/209: BraTS-MEN-01418
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01383: 'preprocessed_data'
#
# 🧠 Processing Case 200/209: BraTS-MEN-01399
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01399: 'preprocessed_data'
#
# 🧠 Processing Case 201/209: BraTS-MEN-01418
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01418: 'preprocessed_data'
#
# 🧠 Processing Case 202/209: BraTS-MEN-01423
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01423: 'preprocessed_data'
#
# 🧠 Processing Case 203/209: BraTS-MEN-01435
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01418: 'preprocessed_data'
#
# 🧠 Processing Case 202/209: BraTS-MEN-01423
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01423: 'preprocessed_data'
#
# 🧠 Processing Case 203/209: BraTS-MEN-01435
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01435: 'preprocessed_data'
#
# 🧠 Processing Case 204/209: BraTS-PED-00097
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-PED-00097: 'preprocessed_data'
#
# 🧠 Processing Case 205/209: BraTS-PED-00103
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-MEN-01435: 'preprocessed_data'
#
# 🧠 Processing Case 204/209: BraTS-PED-00097
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-PED-00097: 'preprocessed_data'
#
# 🧠 Processing Case 205/209: BraTS-PED-00103
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-PED-00103: 'preprocessed_data'
#
# 🧠 Processing Case 206/209: BraTS-PED-00111
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-PED-00111: 'preprocessed_data'
#
# 🧠 Processing Case 207/209: BraTS-PED-00143
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-PED-00103: 'preprocessed_data'
#
# 🧠 Processing Case 206/209: BraTS-PED-00111
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-PED-00111: 'preprocessed_data'
#
# 🧠 Processing Case 207/209: BraTS-PED-00143
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-PED-00143: 'preprocessed_data'
#
# 🧠 Processing Case 208/209: BraTS-PED-00155
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-PED-00155: 'preprocessed_data'
#
# 🧠 Processing Case 209/209: BraTS-PED-00192
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-PED-00143: 'preprocessed_data'
#
# 🧠 Processing Case 208/209: BraTS-PED-00155
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-PED-00155: 'preprocessed_data'
#
# 🧠 Processing Case 209/209: BraTS-PED-00192
# ────────────────────────────────────────────────────────────
# ❌ Error processing BraTS-PED-00192: 'preprocessed_data'
#
# 🎯 INFERENCE SUMMARY:
# ├── Total cases processed: 0
# ├── Total processing time: 0.0s
# └── Average time per case: 0.00s
# ❌ Error processing BraTS-PED-00192: 'preprocessed_data'
#
# 🎯 INFERENCE SUMMARY:
# ├── Total cases processed: 0
# ├── Total processing time: 0.0s
# └── Average time per case: 0.00s

# %%
if inference_results:
    print(f"\n📊 VISUALIZING INFERENCE RESULTS...")
    
    for i, result in enumerate(inference_results[:3]):
        case_id = result['case_id']
        prediction_mask = result['prediction_mask']
        probability_map = result['probability_map']
        
        print(f"\n🧠 Visualizing Case: {case_id}")
        
        fig, axes = plt.subplots(2, 3, figsize=(15, 10))
        fig.suptitle(f'3D Brain Tumor Segmentation Results: {case_id}', fontsize=16, fontweight='bold')
        
        mid_slice = prediction_mask.shape[2] // 2
        
        slice_indices = [
            max(0, mid_slice - 10),
            mid_slice,
            min(prediction_mask.shape[2] - 1, mid_slice + 10)
        ]
        
        for j, slice_idx in enumerate(slice_indices):
            prob_slice = probability_map[:, :, slice_idx]
            mask_slice = prediction_mask[:, :, slice_idx]
            
            axes[0, j].imshow(prob_slice, cmap='hot', vmin=0, vmax=1)
            axes[0, j].set_title(f'Probability Map - Slice {slice_idx}', fontweight='bold')
            axes[0, j].axis('off')
            
            overlay = np.zeros((*mask_slice.shape, 3))
            overlay[mask_slice > 0] = [1, 0, 0]
            
            axes[1, j].imshow(prob_slice, cmap='gray', alpha=0.7)
            axes[1, j].imshow(overlay, alpha=0.5)
            axes[1, j].set_title(f'Segmentation Overlay - Slice {slice_idx}', fontweight='bold')
            axes[1, j].axis('off')
        
        plt.tight_layout()
        
        if len(inference_results) <= 3:
            plt.show()
        else:
            output_vis_dir = Path(config.output_dir) / "visualizations"
            output_vis_dir.mkdir(parents=True, exist_ok=True)
            plot_path = output_vis_dir / f"{case_id}_segmentation_results.png"
            plt.savefig(plot_path, dpi=300, bbox_inches='tight')
            plt.close()
            print(f"📊 Visualization saved: {plot_path}")

print(f"\n📈 GENERATING INFERENCE SUMMARY REPORT...")

summary_report = {
    'inference_summary': {
        'total_cases': len(test_cases),
        'successful_cases': len(inference_results),
        'failed_cases': len(test_cases) - len(inference_results),
        'total_processing_time_seconds': total_inference_time,
        'average_time_per_case_seconds': total_inference_time / max(len(inference_results), 1),
        'config': {
            'model_name': config.model_name,
            'input_size': config.input_size,
            'use_tta': use_tta,
            'use_uncertainty': use_uncertainty,
            'confidence_threshold': confidence_threshold,
            'mixed_precision': config.mixed_precision
        }
    },
    'case_results': []
}

for result in inference_results:
    tumor_volume = np.sum(result['prediction_mask'])
    tumor_percentage = (tumor_volume / np.prod(result['prediction_mask'].shape)) * 100
    
    case_summary = {
        'case_id': result['case_id'],
        'inference_time_seconds': result['inference_time'],
        'tumor_detected': tumor_volume > 0,
        'tumor_volume_voxels': int(tumor_volume),
        'tumor_percentage': round(tumor_percentage, 2),
        'max_probability': round(float(np.max(result['probability_map'])), 4),
        'mean_tumor_probability': round(float(np.mean(result['probability_map'][result['prediction_mask'] > 0])), 4) if tumor_volume > 0 else 0,
        'volume_shape': result['prediction_mask'].shape,
        'confidence_threshold': result['confidence_threshold']
    }
    
    if result.get('uncertainty_map') is not None:
        case_summary['mean_uncertainty'] = round(float(np.mean(result['uncertainty_map'][result['prediction_mask'] > 0])), 4) if tumor_volume > 0 else 0
    
    summary_report['case_results'].append(case_summary)

report_output_dir = Path(config.output_dir)
report_output_dir.mkdir(parents=True, exist_ok=True)

report_path = report_output_dir / "inference_summary_report.json"
with open(report_path, 'w') as f:
    json.dump(summary_report, f, indent=2)

print(f"✅ Inference summary report saved: {report_path}")

print(f"\n📋 FINAL INFERENCE REPORT:")
print("=" * 80)
tumor_cases = [r for r in inference_results if np.sum(r['prediction_mask']) > 0]
print(f"🔍 DETECTION SUMMARY:")
print(f"├── Cases processed: {len(inference_results)}")
print(f"├── Tumors detected: {len(tumor_cases)}")
print(f"├── Detection rate: {len(tumor_cases)/max(len(inference_results), 1)*100:.1f}%")
print(f"└── False negative rate: {(len(inference_results)-len(tumor_cases))/max(len(inference_results), 1)*100:.1f}%")

if tumor_cases:
    volumes = [np.sum(r['prediction_mask']) for r in tumor_cases]
    probabilities = [np.max(r['probability_map']) for r in tumor_cases]
    
    print(f"\n📊 TUMOR CHARACTERISTICS:")
    print(f"├── Average volume: {np.mean(volumes):.0f} voxels")
    print(f"├── Volume range: {np.min(volumes):.0f} - {np.max(volumes):.0f} voxels")
    print(f"├── Average max probability: {np.mean(probabilities):.4f}")
    print(f"└── Probability range: {np.min(probabilities):.4f} - {np.max(probabilities):.4f}")

print(f"\n⚡ PERFORMANCE METRICS:")
print(f"├── Total processing time: {format_time(total_inference_time)}")
print(f"├── Average time per case: {total_inference_time/max(len(inference_results), 1):.2f}s")
if total_inference_time > 0:
    print(f"├── Throughput: {len(inference_results)/total_inference_time*60:.1f} cases/minute")
else:
    print(f"├── Throughput: N/A (no processing time recorded)")
print(f"└── Model parameters: {num_params:,}")

print(f"\n🎉 3D BRAIN TUMOR SEGMENTATION INFERENCE COMPLETE!")
print(f"🔥 PRODUCTION-READY | GPU ACCELERATED | UNCERTAINTY AWARE")
print(f"💾 Results saved to: {config.output_dir}")
print("=" * 80)
# Out:
# 📈 GENERATING INFERENCE SUMMARY REPORT...
# ✅ Inference summary report saved: c:\Users\surya\NueroVisionAI\outputs\3d\inference_summary_report.json
#
# 📋 FINAL INFERENCE REPORT:
# ================================================================================
# 🔍 DETECTION SUMMARY:
# ├── Cases processed: 0
# ├── Tumors detected: 0
# ├── Detection rate: 0.0%
# └── False negative rate: 0.0%
#
# ⚡ PERFORMANCE METRICS:
# ├── Total processing time: 0.0s
# ├── Average time per case: 0.00s
# ├── Throughput: N/A (no processing time recorded)
# └── Model parameters: 1,402,561
#
# 🎉 3D BRAIN TUMOR SEGMENTATION INFERENCE COMPLETE!
# 🔥 PRODUCTION-READY | GPU ACCELERATED | UNCERTAINTY AWARE
# 💾 Results saved to: c:\Users\surya\NueroVisionAI\outputs\3d
# ================================================================================
